# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
dr_str = f'dr_02'

for alpha in range(1,5):
    
    lr_str = f'lr_1e-{alpha}'
    #Names of directories to access
    directory = f'hyperParameterSearch/{lr_str}_{dr_str}/'
    
    print(f'LearningRate: 1e-{alpha}, Dropout: 0.2')
    #Names of files to access
    training_loss_str   = f'{directory}train_loss_{lr_str}_{dr_str}_avg.csv'
    validation_loss_str = f'{directory}valid_loss_{lr_str}_{dr_str}_avg.csv'
    training_accu_str    = f'{directory}train_accu_{lr_str}_{dr_str}_avg.csv'
    validation_accu_str  = f'{directory}valid_accu_{lr_str}_{dr_str}_avg.csv'
    '''
    #Read Data
    training_loss_df    = pd.read_csv(training_loss_str)
    validation_loss_df  = pd.read_csv(validation_loss_str)
    training_acc_df     = pd.read_csv(training_acc_str)
    validation_acc_df   = pd.read_csv(validation_acc_str)
    '''
    #Read Data
    training_loss_df    = np.loadtxt(training_loss_str)
    validation_loss_df  = np.loadtxt(validation_loss_str)
    training_accu_df     = np.loadtxt(training_accu_str)
    validation_accu_df   = np.loadtxt(validation_accu_str)
    ###########Plot, label, save###########
    # LOSS
    plt.plot(training_loss_df,label='Training')
    plt.plot(validation_loss_df,label='Validation')
    plt.title(f'Loss: LR={10**(-alpha)}, DR=0.2')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    #plt.savefig(f'lr_10e_{alpha}_split{split_str}_loss.pdf')
    plt.show()
    # ACCURACY
    plt.plot(training_accu_df,label='Training')
    plt.plot(validation_accu_df,label='Validation')
    plt.title(f'Accuracy: LR={10**(-alpha)}, DR=0.2')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    #plt.savefig(f'lr_10e_{alpha}_split{split_str}_acc.pdf')
    plt.show()
# Out:
# LearningRate: 1e-1, Dropout: 0.2
# LearningRate: 1e-2, Dropout: 0.2
# LearningRate: 1e-3, Dropout: 0.2
# LearningRate: 1e-4, Dropout: 0.2

# %%
lr_str = f'lr_1e-4'

for alpha in range(1,6):
    
    dr_str = f'dr_0{alpha}'
    #Names of directories to access
    directory = f'hyperParameterSearch/{lr_str}_{dr_str}/'
    
    print(f'LearningRate: 1e-4, Dropout: 0.{alpha}')
    #Names of files to access
    training_loss_str   = f'{directory}train_loss_{lr_str}_{dr_str}_avg.csv'
    validation_loss_str = f'{directory}valid_loss_{lr_str}_{dr_str}_avg.csv'
    training_accu_str    = f'{directory}train_accu_{lr_str}_{dr_str}_avg.csv'
    validation_accu_str  = f'{directory}valid_accu_{lr_str}_{dr_str}_avg.csv'
    '''
    #Read Data
    training_loss_df    = pd.read_csv(training_loss_str)
    validation_loss_df  = pd.read_csv(validation_loss_str)
    training_acc_df     = pd.read_csv(training_acc_str)
    validation_acc_df   = pd.read_csv(validation_acc_str)
    '''
    #Read Data
    training_loss_df    = np.loadtxt(training_loss_str)
    validation_loss_df  = np.loadtxt(validation_loss_str)
    training_accu_df     = np.loadtxt(training_accu_str)
    validation_accu_df   = np.loadtxt(validation_accu_str)
    ###########Plot, label, save###########
    # LOSS
    plt.plot(training_loss_df,label='Training')
    plt.plot(validation_loss_df,label='Validation')
    plt.title(f'Loss: LR={10**(-4)}, DR=0.{alpha}')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    #plt.savefig(f'lr_10e_{alpha}_split{split_str}_loss.pdf')
    plt.show()
    # ACCURACY
    plt.plot(training_accu_df,label='Training')
    plt.plot(validation_accu_df,label='Validation')
    plt.title(f'Accuracy: LR={10**(-4)}, DR=0.{alpha}')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    #plt.savefig(f'lr_10e_{alpha}_split{split_str}_acc.pdf')
    plt.show()
# Out:
# LearningRate: 1e-4, Dropout: 0.1
# LearningRate: 1e-4, Dropout: 0.2
# LearningRate: 1e-4, Dropout: 0.3
# LearningRate: 1e-4, Dropout: 0.4
# LearningRate: 1e-4, Dropout: 0.5
